# %% [markdown]
# ## CSC271 Demo Notebook
#
# This is a simple notebook with one markdown and one code cell.

# %%
import pandas as pd 

df = pd.DataFrame({
    'Name': ['A', 'B', 'C'],
    'Age': [24, 27, 22],
    'Score': [85, 90, 78]
})

df
# Out:
#   Name  Age  Score
# 0    A   24     85
# 1    B   27     90
# 2    C   22     78
